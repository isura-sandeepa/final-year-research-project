# %%
import os
import random
from PIL import Image, ImageOps, ImageDraw
import time
import math
import shutil

max_time = 30

def intersect(box1, box2):
    return not (box1[2] <= box2[0] or box1[0] >= box2[2] or box1[3] <= box2[1] or box1[1] >= box2[3])

def transform(image):
    
    angle = random.uniform(-30, 30)
    # Randomly rotate the image
    image = image.rotate(angle, resample=Image.BICUBIC)

     # Randomly flip the image
    if random.random() > 0.5:
        image = ImageOps.mirror(image)
        
    return image

def transform_box(box, angle):
    
    width =  box[2] - box[0]
    height = box[3] - box[1]

    # Get rotation angle and apply rotation to box coordinates
    angle = angle
    cos_val = abs(math.cos(math.radians(angle)))
    sin_val = abs(math.sin(math.radians(angle)))
    new_x1 = (box[0] - width / 2) * cos_val - (box[1] - height / 2) * sin_val + width / 2
    new_y1 = (box[0] - width / 2) * sin_val + (box[1] - height / 2) * cos_val + height / 2
    new_x2 = (box[2] - width / 2) * cos_val - (box[3] - height / 2) * sin_val + width / 2
    new_y2 = (box[2] - width / 2) * sin_val + (box[3] - height / 2) * cos_val + height / 2

    # Randomly flip the box
    if random.random() > 0.5:
        new_x1, new_x2 = width - new_x2, width - new_x1

    return [new_x1, new_y1, new_x2, new_y2]

def lblformat(box, background_size):
    labelimg_box = [
    (box[0]/ float(background_size)) + ((box[2]-box[0])/ float(background_size))*0.5,#(box1[0]/ float(background_size))*0.5,  # xmin
    (box[1]/ float(background_size))+ ((box[3]-box[1])/ float(background_size))*0.5,#(box1[1]/ float(background_size))*0.5,  # ymin
    (box[2]-box[0])/ float(background_size),  # width
    (box[3]-box[1])/ float(background_size),  # height
    ]
    return labelimg_box

def detect_class(name):
    if 'cardboard' in name:
        return 0
    elif 'glass' in name:
        return 1
    elif 'metal' in name:
        return 2
    elif 'paper' in name:
        return 3
    elif 'plastic' in name:
        return 4
    else:
        return 5

# %%
background_size = 800

directory = 'png_valid'

output_dir = "new_images_valid"  # replace with your directory path

folder_count = len([item for item in os.listdir(output_dir) if os.path.isdir(os.path.join(output_dir , item))])

folder_name = f'exp{folder_count+1}'

new_folder = os.path.join(output_dir, f'exp{folder_count+1}')
os.mkdir(new_folder)

output_dir = new_folder

#copy the classes.txt file to the new folder
source_file = '/Users/casper/Desktop/yolov5/dataset_generator/new_images_train/classes.txt'
filename = os.path.basename(source_file)
destination_file = os.path.join(output_dir, filename)
shutil.copy2(source_file, destination_file)

boxes = []

for i in range (1, 500):
    
    images = [filename for filename in os.listdir(directory) if filename.endswith('.png')]
    bgs = [filename for filename in os.listdir('bgs') if filename.endswith('.png')]
    
    selected_images = random.sample(images, 3)
    random_bg = Image.open(os.path.join('bgs', random.choice(bgs)))
    
    image_names = [os.path.splitext(image)[0] for image in selected_images]
    
    new_image = random_bg.resize((background_size, background_size))
    
    img1 = Image.open(os.path.join(directory, selected_images[0]))
    img1 = img1.convert("RGBA")
    img1 = transform(img1)
    
    scale_factor = random.uniform(0.5, 1)
    
    new_size = tuple(int(dim * scale_factor) for dim in img1.size)
    img1 = img1.resize(new_size)
    
    # Get the bounding box of the non-transparent part of the image
    bbox1 = img1.getbbox()

    # Calculate the width and height of the non-transparent part of the image at the given scale
    width = (bbox1[2] - bbox1[0])
    height = (bbox1[3] - bbox1[1])
    
    x1 = random.uniform(0, background_size - width)
    y1 = random.uniform(0, background_size - height)
    
    box1 = (x1, y1, x1 + width, y1 + height)
    boxes.append(box1)
    
    new_image.paste(img1, (int(x1-bbox1[0]), int(y1-bbox1[1])), img1)

    # Draw rectangles on new image based on box coordinates
    # draw = ImageDraw.Draw(new_image)
    # draw.rectangle(box1, outline="blue")
    
# draw the second box at a random position that does not overlap with the first box
    start_time = time.time()
    placed = False
    
    while not placed:
        
        img2 = Image.open(os.path.join(directory, selected_images[1]))
        img2 = img2.convert("RGBA")
        img2 = transform(img2)
        
        scale_factor = random.uniform(0.5, 1)
            
        new_size = tuple(int(dim * scale_factor) for dim in img2.size)
        img2 = img2.resize(new_size)
        
        # Get the bounding box of the non-transparent part of the image
        bbox2 = img2.getbbox()

        # Calculate the width and height of the non-transparent part of the image at the given scale
        width = (bbox2[2] - bbox2[0])
        height = (bbox2[3] - bbox2[1])
        
        x2 = random.uniform(0, background_size - width)
        y2 = random.uniform(0, background_size - height)
        
        box2 = (x2, y2, x2 + width, y2 + height)
        boxes.append(box2)

        if not any([intersect(box2, box1)]):
            
            new_image.paste(img2, (int(x2-bbox2[0]), int(y2-bbox2[1])), img2)

            # Draw rectangles on new image based on box coordinates
            # draw = ImageDraw.Draw(new_image)
            # draw.rectangle(box2, outline="red")
            
            break
        else:
            # print(f"{i} Retrying with another coordinate...2nd image")
            time.sleep(0.5)


# draw the third box at a random position that does not overlap with the first box
    start_time = time.time()
    placed = False
    
    while not placed:
        
        img3 = Image.open(os.path.join(directory, selected_images[2]))
        img3 = img3.convert("RGBA")
        img3 = transform(img3)
    
        scale_factor = random.uniform(0.5, 1)
            
        new_size = tuple(int(dim * scale_factor) for dim in img3.size)
        img3 = img3.resize(new_size)
        
        # Get the bounding box of the non-transparent part of the image
        bbox3 = img3.getbbox()

        # Calculate the width and height of the non-transparent part of the image at the given scale
        width = (bbox3[2] - bbox3[0])
        height = (bbox3[3] - bbox3[1])
        
        x3 = random.uniform(0, background_size - width)
        y3 = random.uniform(0, background_size - height)
        
        box3 = (x3, y3, x3 + width, y3 + height)
        boxes.append(box3)

        if not any([intersect(box3, box1), intersect(box3, box2)]):
            
            new_image.paste(img3, (int(x3-bbox3[0]), int(y3-bbox3[1])), img3)

            # Draw rectangles on new image based on box coordinates
            # draw = ImageDraw.Draw(new_image)
            # draw.rectangle(box3, outline="green")
            
            break
        else:
            # print(f"{i} Retrying with another coordinate...3rd image")
            time.sleep(0.5)      
                
    new_image_name = f"{i}_{'_'.join(image_names)}_{folder_name}.jpg"
    new_image_path = os.path.join(output_dir, new_image_name)
    new_image.save(new_image_path)
    print(f"{new_image_name} saved")
    
    new_txt_name = f"{output_dir}/{i}_{'_'.join(image_names)}_{folder_name}.txt"
    
    labelimg_box = lblformat(box1, background_size)
    text1 = f"{detect_class(image_names[0])} {labelimg_box[0]} {labelimg_box[1]} {labelimg_box[2]} {labelimg_box[3]}"
    
    labelimg_box = lblformat(box2, background_size)
    text2 = f"{detect_class(image_names[1])} {labelimg_box[0]} {labelimg_box[1]} {labelimg_box[2]} {labelimg_box[3]}"
    
    labelimg_box = lblformat(box3, background_size)
    text3 = f"{detect_class(image_names[2])} {labelimg_box[0]} {labelimg_box[1]} {labelimg_box[2]} {labelimg_box[3]}"

    with open(f"{new_txt_name}", "w") as file:
        file.write(text1 + '\n')
        file.write(text2 + '\n')
        file.write(text3 + '\n')
# Out:
# 1_plastic330_paper14_paper9_exp2.jpg saved
# 2_metal242_metal123_plastic152_exp2.jpg saved
# 3_metal47_plastic9_paper439_exp2.jpg saved
# 4_plastic200_cardboard185_plastic310_exp2.jpg saved
# 5_glass449_metal134_glass40_exp2.jpg saved
# 6_plastic319_plastic139_plastic185_exp2.jpg saved
# 7_glass169_paper558_paper562_exp2.jpg saved
# 8_plastic264_paper512_paper368_exp2.jpg saved
# 9_paper280_plastic304_glass328_exp2.jpg saved
# 10_paper434_cardboard123_plastic414_exp2.jpg saved
# 11_plastic58_trash77_paper217_exp2.jpg saved
# 12_glass124_glass325_paper268_exp2.jpg saved
# 13_trash28_metal104_metal246_exp2.jpg saved
# 14_glass230_plastic285_trash134_exp2.jpg saved
# 15_glass104_glass40_trash106_exp2.jpg saved
# 16_paper185_plastic309_plastic264_exp2.jpg saved
# 17_paper189_paper351_metal204_exp2.jpg saved
# 18_metal197_paper593_glass396_exp2.jpg saved
# 19_glass463_paper546_paper157_exp2.jpg saved
# 20_metal117_paper539_glass276_exp2.jpg saved
# 21_paper268_paper559_metal85_exp2.jpg saved
# 22_paper567_paper512_plastic264_exp2.jpg saved
# 23_plastic12_paper8_glass81_exp2.jpg saved
# 24_trash108_glass90_paper307_exp2.jpg saved
# 25_metal77_paper147_paper407_exp2.jpg saved
# 26_trash121_plastic84_paper16_exp2.jpg saved
# 27_plastic213_glass114_plastic258_exp2.jpg saved
# 28_plastic439_glass416_paper130_exp2.jpg saved
# 29_paper271_paper49_paper483_exp2.jpg saved
# 30_paper167_cardboard24_metal72_exp2.jpg saved
# 31_paper367_paper570_metal382_exp2.jpg saved
# 32_trash27_paper233_metal48_exp2.jpg saved
# 33_plastic324_trash24_metal259_exp2.jpg saved
# 34_plastic103_glass97_glass391_exp2.jpg saved
# 35_trash28_paper301_plastic456_exp2.jpg saved
# 36_plastic237_paper373_plastic319_exp2.jpg saved
# 37_glass270_glass169_paper128_exp2.jpg saved
# 38_metal106_paper512_metal5_exp2.jpg saved
# 39_metal123_metal229_metal270_exp2.jpg saved
# 40_trash150_glass124_cardboard228_exp2.jpg saved
# 41_trash22_glass198_glass245_exp2.jpg saved
# 42_cardboard145_plastic440_paper257_exp2.jpg saved
# 43_glass105_metal111_glass86_exp2.jpg saved
# 44_glass413_cardboard215_glass483_exp2.jpg saved
# 45_paper86_cardboard354_metal239_exp2.jpg saved
# 46_paper294_metal165_metal204_exp2.jpg saved
# 47_plastic261_glass122_glass108_exp2.jpg saved
# 48_paper94_metal309_paper239_exp2.jpg saved
# 49_glass26_metal292_paper572_exp2.jpg saved
# 50_glass2_metal340_plastic237_exp2.jpg saved
# 51_plastic429_plastic213_metal249_exp2.jpg saved
# 52_glass3_cardboard49_paper584_exp2.jpg saved
# 53_metal210_plastic288_plastic439_exp2.jpg saved
# 54_plastic53_glass419_glass268_exp2.jpg saved
# 55_cardboard99_trash44_paper408_exp2.jpg saved
# 56_glass65_paper462_metal111_exp2.jpg saved
# 57_cardboard198_paper423_plastic126_exp2.jpg saved
# 58_glass262_plastic319_metal125_exp2.jpg saved
# 59_glass467_paper590_glass367_exp2.jpg saved
# 60_cardboard54_paper53_paper153_exp2.jpg saved
# 61_glass75_glass378_plastic127_exp2.jpg saved
# 62_trash73_cardboard117_metal277_exp2.jpg saved
# 63_glass412_plastic295_plastic86_exp2.jpg saved
# 64_paper536_glass155_glass328_exp2.jpg saved
# 65_paper341_plastic278_paper593_exp2.jpg saved
# 66_plastic324_paper423_plastic126_exp2.jpg saved
# 67_plastic309_metal48_cardboard41_exp2.jpg saved
# 68_trash25_plastic247_paper512_exp2.jpg saved
# 69_paper451_paper560_plastic103_exp2.jpg saved
# 70_cardboard54_glass62_plastic220_exp2.jpg saved
# 71_plastic334_metal59_paper222_exp2.jpg saved
# 72_plastic405_plastic236_glass93_exp2.jpg saved
# 73_paper455_glass49_paper374_exp2.jpg saved
# 74_glass63_glass413_metal252_exp2.jpg saved
# 75_plastic44_glass412_paper429_exp2.jpg saved
# 76_plastic237_plastic39_paper399_exp2.jpg saved
# 77_plastic310_paper268_paper455_exp2.jpg saved
# 78_trash117_paper33_glass49_exp2.jpg saved
# 79_glass443_metal34_glass10_exp2.jpg saved
# 80_glass299_metal384_metal219_exp2.jpg saved
# 81_trash99_trash152_plastic73_exp2.jpg saved
# 82_paper313_metal165_plastic245_exp2.jpg saved
# 83_cardboard132_cardboard177_metal117_exp2.jpg saved
# 84_metal243_paper582_paper148_exp2.jpg saved
# 85_glass75_paper21_glass400_exp2.jpg saved
# 86_plastic154_glass309_paper456_exp2.jpg saved
# 87_metal105_plastic58_trash151_exp2.jpg saved
# 88_glass443_plastic435_paper502_exp2.jpg saved
# 89_metal249_paper559_plastic152_exp2.jpg saved
# 90_metal74_glass17_metal311_exp2.jpg saved
# 91_paper53_trash123_plastic117_exp2.jpg saved
# 92_paper492_plastic336_metal32_exp2.jpg saved
# 93_paper456_paper302_glass65_exp2.jpg saved
# 94_paper540_paper268_glass262_exp2.jpg saved
# 95_glass309_paper244_glass418_exp2.jpg saved
# 96_paper233_glass461_plastic200_exp2.jpg saved
# 97_plastic177_metal182_paper533_exp2.jpg saved
# 98_glass382_plastic53_plastic49_exp2.jpg saved
# 99_metal200_metal13_metal100_exp2.jpg saved
# 100_plastic289_metal189_trash123_exp2.jpg saved
# 101_paper101_paper244_paper395_exp2.jpg saved
# 102_trash145_glass299_paper147_exp2.jpg saved
# 103_trash106_metal349_glass152_exp2.jpg saved
# 104_cardboard41_paper434_paper437_exp2.jpg saved
# 105_trash123_paper344_trash30_exp2.jpg saved
# 106_metal286_plastic264_plastic303_exp2.jpg saved
# 107_glass71_plastic228_metal195_exp2.jpg saved
# 108_paper147_metal249_trash134_exp2.jpg saved
# 109_plastic264_plastic336_trash82_exp2.jpg saved
# 110_trash149_paper233_plastic213_exp2.jpg saved
# 111_trash63_plastic355_metal123_exp2.jpg saved
# 112_paper271_paper222_paper221_exp2.jpg saved
# 113_trash101_trash27_paper184_exp2.jpg saved
# 114_paper492_trash35_glass372_exp2.jpg saved
# 115_glass371_paper437_cardboard364_exp2.jpg saved
# 116_metal165_cardboard148_glass191_exp2.jpg saved
# 117_plastic192_paper257_plastic119_exp2.jpg saved
# 118_metal53_metal189_trash22_exp2.jpg saved
# 119_trash45_paper16_paper77_exp2.jpg saved
# 120_metal111_glass108_plastic71_exp2.jpg saved
# 121_metal5_plastic455_metal148_exp2.jpg saved
# 122_paper190_metal77_plastic383_exp2.jpg saved
# 123_plastic443_metal189_metal160_exp2.jpg saved
# 124_glass122_glass104_paper495_exp2.jpg saved
# 125_paper130_trash77_paper193_exp2.jpg saved
# 126_metal32_paper378_metal91_exp2.jpg saved
# 127_metal176_metal267_plastic309_exp2.jpg saved
# 128_glass115_paper495_paper552_exp2.jpg saved
# 129_plastic334_plastic201_paper513_exp2.jpg saved
# 130_paper176_plastic258_metal252_exp2.jpg saved
# 131_glass52_glass328_paper120_exp2.jpg saved
# 132_paper367_plastic57_metal182_exp2.jpg saved
# 133_paper289_glass130_paper331_exp2.jpg saved
# 134_glass233_metal34_paper8_exp2.jpg saved
# 135_paper63_glass100_paper570_exp2.jpg saved
# 136_glass128_metal277_cardboard294_exp2.jpg saved
# 137_glass230_cardboard49_paper57_exp2.jpg saved
# 138_glass114_trash134_trash20_exp2.jpg saved
# 139_metal74_glass405_paper407_exp2.jpg saved
# 140_paper361_plastic319_paper284_exp2.jpg saved
# 141_plastic232_paper408_cardboard171_exp2.jpg saved
# 142_cardboard132_metal130_glass469_exp2.jpg saved
# 143_glass462_paper132_paper377_exp2.jpg saved
# 144_plastic134_cardboard204_paper176_exp2.jpg saved
# 145_metal291_glass3_plastic182_exp2.jpg saved
# 146_plastic295_paper332_glass40_exp2.jpg saved
# 147_trash63_paper33_paper570_exp2.jpg saved
# 148_metal220_paper193_plastic403_exp2.jpg saved
# 149_cardboard41_metal311_metal286_exp2.jpg saved
# 150_glass298_plastic443_plastic310_exp2.jpg saved
# 151_glass309_plastic86_cardboard353_exp2.jpg saved
# 152_trash95_paper19_cardboard132_exp2.jpg saved
# 153_plastic374_glass198_plastic119_exp2.jpg saved
# 154_paper453_glass75_glass231_exp2.jpg saved
# 155_plastic285_plastic318_paper536_exp2.jpg saved
# 156_plastic340_paper434_glass409_exp2.jpg saved
# 157_glass299_plastic37_paper153_exp2.jpg saved
# 158_plastic145_glass259_trash28_exp2.jpg saved
# 159_trash151_plastic421_glass122_exp2.jpg saved
# 160_metal389_metal181_plastic117_exp2.jpg saved
# 161_plastic220_paper509_glass382_exp2.jpg saved
# 162_plastic383_metal134_glass96_exp2.jpg saved
# 163_paper495_cardboard334_metal110_exp2.jpg saved
# 164_plastic55_plastic201_plastic216_exp2.jpg saved
# 165_glass10_glass469_paper567_exp2.jpg saved
# 166_plastic353_plastic96_paper403_exp2.jpg saved
# 167_paper244_paper584_trash151_exp2.jpg saved
# 168_plastic385_plastic8_paper512_exp2.jpg saved
# 169_paper168_trash138_cardboard193_exp2.jpg saved
# 170_paper484_metal97_paper115_exp2.jpg saved
# 171_glass169_paper552_plastic435_exp2.jpg saved
# 172_glass302_metal229_plastic273_exp2.jpg saved
# 173_paper512_trash148_glass86_exp2.jpg saved
# 174_glass62_glass153_glass202_exp2.jpg saved
# 175_trash151_paper204_paper193_exp2.jpg saved
# 176_paper241_metal59_metal249_exp2.jpg saved
# 177_plastic292_metal219_cardboard24_exp2.jpg saved
# 178_metal249_plastic103_paper294_exp2.jpg saved
# 179_paper492_glass207_metal286_exp2.jpg saved
# 180_plastic177_paper337_trash82_exp2.jpg saved
# 181_plastic435_glass26_paper560_exp2.jpg saved
# 182_paper57_trash45_paper65_exp2.jpg saved
# 183_cardboard175_glass277_metal160_exp2.jpg saved
# 184_metal303_trash121_paper370_exp2.jpg saved
# 185_glass499_glass418_cardboard362_exp2.jpg saved
# 186_plastic348_plastic400_trash150_exp2.jpg saved
# 187_plastic403_plastic258_glass233_exp2.jpg saved
# 188_plastic388_plastic324_glass97_exp2.jpg saved
# 189_trash27_metal303_paper302_exp2.jpg saved
# 190_plastic258_glass311_glass55_exp2.jpg saved
# 191_glass426_paper329_paper221_exp2.jpg saved
# 192_paper590_paper289_plastic127_exp2.jpg saved
# 193_plastic264_glass367_metal59_exp2.jpg saved
# 194_plastic278_cardboard171_glass499_exp2.jpg saved
# 195_metal140_plastic37_glass90_exp2.jpg saved
# 196_glass372_plastic353_metal42_exp2.jpg saved
# 197_glass422_glass380_metal203_exp2.jpg saved
# 198_trash106_plastic272_glass380_exp2.jpg saved
# 199_metal32_metal124_glass108_exp2.jpg saved
# 200_glass215_trash108_glass245_exp2.jpg saved
# 201_paper38_glass336_plastic425_exp2.jpg saved
# 202_glass169_paper130_glass96_exp2.jpg saved
# 203_plastic285_plastic53_paper94_exp2.jpg saved
# 204_cardboard123_glass105_glass462_exp2.jpg saved
# 205_glass198_paper237_plastic448_exp2.jpg saved
# 206_plastic385_metal148_paper381_exp2.jpg saved
# 207_glass168_glass318_paper367_exp2.jpg saved
# 208_glass240_paper301_glass412_exp2.jpg saved
# 209_paper307_glass155_glass393_exp2.jpg saved
# 210_trash30_metal105_paper239_exp2.jpg saved
# 211_glass100_paper590_plastic285_exp2.jpg saved
# 212_plastic295_glass378_metal282_exp2.jpg saved
# 213_glass63_glass326_paper560_exp2.jpg saved
# 214_paper403_paper103_plastic342_exp2.jpg saved
# 215_plastic414_glass428_glass318_exp2.jpg saved
# 216_trash138_metal97_cardboard217_exp2.jpg saved
# 217_paper53_paper268_paper271_exp2.jpg saved
# 218_glass108_glass268_paper392_exp2.jpg saved
# 219_plastic267_paper301_metal311_exp2.jpg saved
# 220_cardboard188_paper519_paper373_exp2.jpg saved
# 221_glass463_cardboard294_paper237_exp2.jpg saved
# 222_cardboard136_plastic218_cardboard161_exp2.jpg saved
# 223_glass55_paper513_plastic219_exp2.jpg saved
# 224_paper407_metal282_plastic57_exp2.jpg saved
# 225_paper449_trash101_paper408_exp2.jpg saved
# 226_glass152_cardboard188_paper250_exp2.jpg saved
# 227_glass447_metal207_metal48_exp2.jpg saved
# 228_metal37_plastic180_paper399_exp2.jpg saved
# 229_paper289_glass412_trash99_exp2.jpg saved
# 230_paper114_plastic218_glass300_exp2.jpg saved
# 231_cardboard358_paper590_glass348_exp2.jpg saved
# 232_glass499_paper38_plastic310_exp2.jpg saved
# 233_glass347_trash30_paper439_exp2.jpg saved
# 234_metal53_plastic55_glass447_exp2.jpg saved
# 235_paper495_glass225_plastic295_exp2.jpg saved
# 236_metal200_metal169_glass393_exp2.jpg saved
# 237_metal140_glass117_paper204_exp2.jpg saved
# 238_paper115_glass230_glass114_exp2.jpg saved
# 239_paper130_metal117_paper399_exp2.jpg saved
# 240_glass26_plastic180_trash103_exp2.jpg saved
# 241_metal270_trash64_cardboard202_exp2.jpg saved
# 242_glass240_cardboard3_plastic340_exp2.jpg saved
# 243_cardboard182_paper327_plastic25_exp2.jpg saved
# 244_paper513_paper439_plastic448_exp2.jpg saved
# 245_paper307_glass409_plastic388_exp2.jpg saved
# 246_cardboard188_plastic273_metal13_exp2.jpg saved
# 247_glass334_glass104_glass364_exp2.jpg saved
# 248_plastic25_plastic48_metal59_exp2.jpg saved
# 249_plastic456_paper176_trash78_exp2.jpg saved
# 250_plastic70_paper301_trash108_exp2.jpg saved
# 251_metal408_metal80_plastic383_exp2.jpg saved
# 252_plastic96_paper182_plastic122_exp2.jpg saved
# 253_glass206_glass413_glass124_exp2.jpg saved
# 254_metal282_glass152_plastic203_exp2.jpg saved
# 255_trash126_trash108_plastic421_exp2.jpg saved
# 256_paper120_glass19_paper193_exp2.jpg saved
# 257_glass105_metal238_paper546_exp2.jpg saved
# 258_paper500_glass412_plastic209_exp2.jpg saved
# 259_trash152_trash128_paper584_exp2.jpg saved
# 260_plastic71_plastic405_paper329_exp2.jpg saved
# 261_paper540_glass447_plastic435_exp2.jpg saved
# 262_metal207_trash126_glass469_exp2.jpg saved
# 263_paper128_trash20_trash63_exp2.jpg saved
# 264_glass409_plastic295_metal167_exp2.jpg saved
# 265_glass347_metal105_plastic335_exp2.jpg saved
# 266_plastic420_paper546_glass153_exp2.jpg saved
# 267_paper480_plastic139_paper268_exp2.jpg saved
# 268_glass207_glass153_paper509_exp2.jpg saved
# 269_metal100_glass26_glass316_exp2.jpg saved
# 270_glass231_paper233_glass55_exp2.jpg saved
# 271_glass105_glass169_trash102_exp2.jpg saved
# 272_metal295_glass372_metal229_exp2.jpg saved
# 273_paper307_plastic318_glass59_exp2.jpg saved
# 274_metal303_paper148_plastic71_exp2.jpg saved
# 275_trash45_trash27_paper63_exp2.jpg saved
# 276_metal389_trash99_plastic280_exp2.jpg saved
# 277_glass196_paper194_plastic245_exp2.jpg saved
# 278_glass122_plastic209_glass278_exp2.jpg saved
# 279_plastic432_paper157_glass206_exp2.jpg saved
# 280_trash128_glass152_paper344_exp2.jpg saved
# 281_metal210_glass351_plastic464_exp2.jpg saved
# 282_glass201_glass105_plastic70_exp2.jpg saved
# 283_paper147_plastic29_plastic103_exp2.jpg saved
# 284_paper9_plastic228_paper94_exp2.jpg saved
# 285_glass382_glass82_trash28_exp2.jpg saved
# 286_paper472_glass299_plastic273_exp2.jpg saved
# 287_glass99_plastic57_plastic246_exp2.jpg saved
# 288_paper101_cardboard229_metal200_exp2.jpg saved
# 289_plastic22_plastic122_plastic73_exp2.jpg saved
# 290_plastic258_plastic340_glass135_exp2.jpg saved
# 291_plastic37_metal207_glass262_exp2.jpg saved
# 292_plastic182_paper125_metal42_exp2.jpg saved
# 293_glass276_paper513_paper370_exp2.jpg saved
# 294_paper478_glass62_paper49_exp2.jpg saved
# 295_paper189_metal12_glass299_exp2.jpg saved
# 296_glass7_plastic87_cardboard152_exp2.jpg saved
# 297_plastic11_cardboard215_metal219_exp2.jpg saved
# 298_metal37_plastic292_trash102_exp2.jpg saved
# 299_glass93_metal195_paper275_exp2.jpg saved
# 300_glass169_metal117_metal282_exp2.jpg saved
# 301_plastic411_glass62_paper434_exp2.jpg saved
# 302_plastic329_paper8_glass405_exp2.jpg saved
# 303_plastic93_paper16_glass152_exp2.jpg saved
# 304_paper185_paper451_plastic11_exp2.jpg saved
# 305_paper572_paper221_plastic435_exp2.jpg saved
# 306_glass128_glass285_plastic93_exp2.jpg saved
# 307_paper237_trash126_glass428_exp2.jpg saved
# 308_plastic213_plastic9_plastic87_exp2.jpg saved
# 309_cardboard33_glass153_plastic386_exp2.jpg saved
# 310_glass152_plastic335_glass10_exp2.jpg saved
# 311_glass499_cardboard202_metal259_exp2.jpg saved
# 312_plastic278_plastic425_paper551_exp2.jpg saved
# 313_trash24_glass499_metal70_exp2.jpg saved
# 314_paper19_paper423_paper271_exp2.jpg saved
# 315_glass293_trash12_cardboard177_exp2.jpg saved
# 316_trash112_metal246_paper546_exp2.jpg saved
# 317_glass334_glass371_glass3_exp2.jpg saved
# 318_metal117_metal140_plastic122_exp2.jpg saved
# 319_plastic219_glass47_metal295_exp2.jpg saved
# 320_metal176_trash24_glass334_exp2.jpg saved
# 321_paper439_glass62_glass77_exp2.jpg saved
# 322_glass124_trash152_plastic156_exp2.jpg saved
# 323_cardboard117_glass483_metal49_exp2.jpg saved
# 324_paper492_glass99_plastic11_exp2.jpg saved
# 325_paper189_paper337_plastic289_exp2.jpg saved
# 326_glass202_plastic3_paper312_exp2.jpg saved
# 327_plastic261_glass498_glass231_exp2.jpg saved
# 328_glass52_metal378_paper365_exp2.jpg saved
# 329_plastic83_plastic25_paper407_exp2.jpg saved
# 330_plastic212_paper562_paper271_exp2.jpg saved
# 331_cardboard193_cardboard114_glass7_exp2.jpg saved
# 332_glass418_trash30_paper339_exp2.jpg saved
# 333_paper128_metal181_paper25_exp2.jpg saved
# 334_glass135_glass371_glass441_exp2.jpg saved
# 335_cardboard49_paper92_glass336_exp2.jpg saved
# 336_glass419_plastic355_plastic172_exp2.jpg saved
# 337_plastic278_metal292_glass109_exp2.jpg saved
# 338_glass334_glass207_glass180_exp2.jpg saved
# 339_metal303_glass441_metal47_exp2.jpg saved
# 340_glass462_trash44_paper9_exp2.jpg saved
# 341_paper244_metal72_cardboard228_exp2.jpg saved
# 342_trash64_plastic134_plastic425_exp2.jpg saved
# 343_paper456_trash128_trash108_exp2.jpg saved
# 344_paper331_glass409_glass17_exp2.jpg saved
# 345_paper513_glass454_plastic420_exp2.jpg saved
# 346_trash15_metal193_paper14_exp2.jpg saved
# 347_paper494_plastic173_metal249_exp2.jpg saved
# 348_cardboard358_plastic12_plastic201_exp2.jpg saved
# 349_paper381_plastic182_glass164_exp2.jpg saved
# 350_paper500_plastic440_paper217_exp2.jpg saved
# 351_plastic228_plastic50_plastic200_exp2.jpg saved
# 352_glass81_paper184_plastic353_exp2.jpg saved
# 353_metal79_metal167_paper579_exp2.jpg saved
# 354_plastic15_glass450_paper584_exp2.jpg saved
# 355_paper449_glass461_glass201_exp2.jpg saved
# 356_glass382_paper158_cardboard154_exp2.jpg saved
# 357_paper423_paper327_paper502_exp2.jpg saved
# 358_glass426_paper495_paper434_exp2.jpg saved
# 359_paper57_metal181_plastic340_exp2.jpg saved
# 360_glass348_metal270_paper344_exp2.jpg saved
# 361_plastic400_plastic388_glass298_exp2.jpg saved
# 362_metal242_plastic443_metal110_exp2.jpg saved
# 363_paper449_glass77_metal340_exp2.jpg saved
# 364_paper588_paper551_glass334_exp2.jpg saved
# 365_paper174_glass483_paper408_exp2.jpg saved
# 366_glass97_paper448_paper434_exp2.jpg saved
# 367_cardboard49_paper456_paper337_exp2.jpg saved
# 368_paper88_paper484_plastic414_exp2.jpg saved
# 369_glass233_glass325_glass422_exp2.jpg saved
# 370_paper341_cardboard358_metal169_exp2.jpg saved
# 371_glass454_paper310_metal220_exp2.jpg saved
# 372_cardboard123_glass483_paper567_exp2.jpg saved
# 373_metal97_glass114_cardboard54_exp2.jpg saved
# 374_paper44_metal182_plastic44_exp2.jpg saved
# 375_plastic172_glass195_cardboard185_exp2.jpg saved
# 376_cardboard117_glass2_trash73_exp2.jpg saved
# 377_plastic455_plastic425_plastic55_exp2.jpg saved
# 378_glass180_plastic316_plastic83_exp2.jpg saved
# 379_metal176_plastic453_cardboard353_exp2.jpg saved
# 380_plastic348_paper546_metal267_exp2.jpg saved
# 381_plastic213_plastic212_cardboard99_exp2.jpg saved
# 382_paper512_paper68_cardboard204_exp2.jpg saved
# 383_glass10_glass122_metal34_exp2.jpg saved
# 384_paper214_metal48_plastic237_exp2.jpg saved
# 385_cardboard3_paper16_cardboard132_exp2.jpg saved
# 386_cardboard185_plastic439_glass135_exp2.jpg saved
# 387_plastic464_cardboard364_glass380_exp2.jpg saved
# 388_metal130_metal176_paper423_exp2.jpg saved
# 389_plastic261_glass443_plastic440_exp2.jpg saved
# 390_trash39_plastic336_glass152_exp2.jpg saved
# 391_cardboard188_paper367_glass90_exp2.jpg saved
# 392_metal70_glass371_metal117_exp2.jpg saved
# 393_paper129_paper368_trash73_exp2.jpg saved
# 394_paper495_metal182_paper448_exp2.jpg saved
# 395_metal382_paper68_metal246_exp2.jpg saved
# 396_glass43_cardboard167_plastic348_exp2.jpg saved
# 397_paper14_glass185_glass432_exp2.jpg saved
# 398_paper275_glass278_plastic322_exp2.jpg saved
# 399_trash63_plastic237_trash64_exp2.jpg saved
# 400_paper182_glass109_metal195_exp2.jpg saved
# 401_paper365_plastic424_paper562_exp2.jpg saved
# 402_cardboard24_paper284_metal143_exp2.jpg saved
# 403_glass285_paper301_glass109_exp2.jpg saved
# 404_paper430_metal242_metal202_exp2.jpg saved
# 405_trash47_metal249_glass463_exp2.jpg saved
# 406_plastic297_plastic48_paper233_exp2.jpg saved
# 407_plastic329_metal311_cardboard362_exp2.jpg saved
# 408_paper118_plastic103_metal202_exp2.jpg saved
# 409_glass298_paper154_metal193_exp2.jpg saved
# 410_cardboard228_glass297_paper559_exp2.jpg saved
# 411_metal55_metal59_metal26_exp2.jpg saved
# 412_plastic261_paper244_glass122_exp2.jpg saved
# 413_glass150_plastic247_metal22_exp2.jpg saved
# 414_paper268_plastic332_paper327_exp2.jpg saved
# 415_plastic126_glass63_paper555_exp2.jpg saved
# 416_plastic335_metal249_metal252_exp2.jpg saved
# 417_paper407_glass207_metal165_exp2.jpg saved
# 418_paper453_metal195_paper88_exp2.jpg saved
# 419_glass273_cardboard228_metal292_exp2.jpg saved
# 420_plastic278_paper572_plastic258_exp2.jpg saved
# 421_paper403_paper407_plastic3_exp2.jpg saved
# 422_glass52_paper273_plastic176_exp2.jpg saved
# 423_paper153_metal125_paper129_exp2.jpg saved
# 424_paper540_plastic172_plastic272_exp2.jpg saved
# 425_metal315_plastic319_plastic149_exp2.jpg saved
# 426_glass207_cardboard350_glass372_exp2.jpg saved
# 427_paper185_plastic15_glass207_exp2.jpg saved
# 428_glass418_glass231_glass336_exp2.jpg saved
# 429_plastic275_paper310_metal238_exp2.jpg saved
# 430_metal21_glass314_glass62_exp2.jpg saved
# 431_glass314_glass231_glass93_exp2.jpg saved
# 432_plastic44_paper174_cardboard167_exp2.jpg saved
# 433_cardboard132_plastic122_paper330_exp2.jpg saved
# 434_plastic267_glass293_plastic456_exp2.jpg saved
# 435_metal378_glass77_metal197_exp2.jpg saved
# 436_metal267_glass40_glass152_exp2.jpg saved
# 437_trash99_trash27_paper456_exp2.jpg saved
# 438_glass378_paper276_cardboard161_exp2.jpg saved
# 439_glass409_trash24_plastic201_exp2.jpg saved
# 440_paper68_plastic58_paper478_exp2.jpg saved
# 441_paper157_metal26_plastic212_exp2.jpg saved
# 442_glass233_plastic139_glass300_exp2.jpg saved
# 443_plastic236_paper215_trash77_exp2.jpg saved
# 444_paper233_glass309_glass134_exp2.jpg saved
# 445_plastic160_trash47_glass195_exp2.jpg saved
# 446_metal358_metal165_cardboard177_exp2.jpg saved
# 447_trash151_paper546_cardboard215_exp2.jpg saved
# 448_plastic219_plastic119_glass469_exp2.jpg saved
# 449_paper184_paper154_paper546_exp2.jpg saved
# 450_paper455_glass75_plastic12_exp2.jpg saved
# 451_metal72_metal193_paper533_exp2.jpg saved
# 452_glass413_glass63_paper593_exp2.jpg saved
# 453_plastic374_cardboard49_metal259_exp2.jpg saved
# 454_cardboard99_trash44_glass371_exp2.jpg saved
# 455_metal130_glass371_plastic258_exp2.jpg saved
# 456_cardboard145_metal123_plastic220_exp2.jpg saved
# 457_trash121_plastic3_metal349_exp2.jpg saved
# 458_metal210_metal42_glass153_exp2.jpg saved
# 459_glass311_plastic425_metal259_exp2.jpg saved
# 460_plastic119_plastic53_plastic237_exp2.jpg saved
# 461_trash126_paper570_paper25_exp2.jpg saved
# 462_paper273_cardboard364_paper63_exp2.jpg saved
# 463_glass233_paper168_plastic447_exp2.jpg saved
# 464_paper182_plastic83_metal309_exp2.jpg saved
# 465_plastic156_trash45_paper217_exp2.jpg saved
# 466_paper588_plastic304_metal148_exp2.jpg saved
# 467_paper275_glass225_glass328_exp2.jpg saved
# 468_paper582_paper68_plastic405_exp2.jpg saved
# 469_metal22_paper19_trash47_exp2.jpg saved
# 470_trash128_paper344_glass280_exp2.jpg saved
# 471_glass293_plastic127_paper555_exp2.jpg saved
# 472_cardboard358_metal195_cardboard204_exp2.jpg saved
# 473_paper182_cardboard33_glass396_exp2.jpg saved
# 474_plastic435_metal107_plastic316_exp2.jpg saved
# 475_paper35_plastic73_trash126_exp2.jpg saved
# 476_plastic216_paper307_cardboard49_exp2.jpg saved
# 477_trash102_paper378_cardboard364_exp2.jpg saved
# 478_glass336_glass114_cardboard148_exp2.jpg saved
# 479_plastic57_trash15_metal181_exp2.jpg saved
# 480_trash82_plastic55_glass209_exp2.jpg saved
# 481_glass498_plastic176_glass90_exp2.jpg saved
# 482_trash78_plastic280_metal212_exp2.jpg saved
# 483_glass441_plastic70_cardboard123_exp2.jpg saved
# 484_cardboard161_paper567_paper582_exp2.jpg saved
# 485_glass367_metal5_plastic201_exp2.jpg saved
# 486_paper192_glass413_plastic8_exp2.jpg saved
# 487_cardboard145_paper480_paper101_exp2.jpg saved
# 488_paper153_paper378_plastic29_exp2.jpg saved
# 489_trash117_plastic117_metal295_exp2.jpg saved
# 490_glass206_paper49_plastic145_exp2.jpg saved
# 491_metal277_plastic203_paper250_exp2.jpg saved
# 492_cardboard364_glass414_plastic218_exp2.jpg saved
# 493_cardboard227_paper344_cardboard148_exp2.jpg saved
# 494_paper168_metal318_glass277_exp2.jpg saved
# 495_paper423_cardboard185_paper94_exp2.jpg saved
# 496_plastic71_cardboard204_glass467_exp2.jpg saved
# 497_glass114_paper289_paper565_exp2.jpg saved
# 498_paper367_plastic332_plastic48_exp2.jpg saved
# 499_plastic386_glass396_metal267_exp2.jpg saved
